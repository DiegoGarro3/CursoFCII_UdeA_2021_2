# %%
# %pylab inline
from matplotlib.pyplot import *
from mpl_toolkits.mplot3d import axes3d
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos=[]
with open("posicion.txt") as fname:
    for lineas in fname:
        datos.append(lineas.split())

Datos=np.array(datos[1:])

xpos=Datos[:,1].astype(float)
ypos=Datos[:,2].astype(float)
zpos=Datos[:,3].astype(float)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.gca(projection='3d')
ax.plot(xpos, xpos, Zpos,"b", label="Radio = 1.5 \ndt = 0.1 \ntTotal = 3.2 \nFrecuencia = 2  \nFase = Pi/4 \nz0 = 0.5 \nvz = 2.1") 
plt.title('Posición de la partícula')
plt.legend()
plt.savefig("Grafica de la posición.jpg")
plt.show()
