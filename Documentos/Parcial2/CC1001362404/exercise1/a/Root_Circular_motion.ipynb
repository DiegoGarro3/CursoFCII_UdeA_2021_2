// %%
{
    TCanvas *c = new TCanvas("c","Graph2D",400,400);

    TGraph *dt = new TGraph("datos.txt");
    dt->SetTitle("Motion of a Charged Particle; X ; Y");
    
    dt->SetMarkerColor(36);
    dt->SetMarkerSize(0.5);
    dt->SetMarkerStyle(4);

    dt->Draw();
    c->Draw();
    return c;
}
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
