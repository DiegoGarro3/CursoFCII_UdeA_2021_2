# %%
# %pylab inline
import pandas as pd
from mpl_toolkits import mplot3d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
espiralDat = pd.read_table("posiciónEspiral.txt",sep="\s+")

# %%
espiralDat.head()
# Out:
#    time      xPos    yPos  zPos
# 0   0.0  1.060700  1.0607  0.50
# 1   0.1  0.828800  1.2502  0.71
# 2   0.2  0.563890  1.3900  0.92
# 3   0.3  0.276510  1.4743  1.13
# 4   0.4 -0.021902  1.4998  1.34

# %%
fig = plt.figure(figsize=(6,4))
ax = plt.axes(projection='3d')

x = espiralDat['xPos']
y = espiralDat['yPos']
z = espiralDat['zPos']

ax.scatter(x,y,z)

ax.set_xlabel('xPos')
ax.set_ylabel('yPos')
ax.set_zlabel('zPos')
ax.set_title('Trayectoria Espiral')

savefig("EspiralGraf")

plt.show()
